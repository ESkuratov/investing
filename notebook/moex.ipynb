# %%
import requests
import apimoex
import pandas as pd
import pathlib
import plotly.express as px

# %%
board = 'TQBR'

# %%
with requests.Session() as session:
    data = apimoex.get_board_history(session, 'MOEX')
    df = pd.DataFrame(data)

# %%
df.tail()
# Out:
#      BOARDID   TRADEDATE   CLOSE    VOLUME         VALUE
# 1855    TQBR  2020-08-20  144.35   8058350  1.161053e+09
# 1856    TQBR  2020-08-21  146.18  12934090  1.871029e+09
# 1857    TQBR  2020-08-24  145.72   9898460  1.450250e+09
# 1858    TQBR  2020-08-25  143.72   7191980  1.034097e+09
# 1859    TQBR  2020-08-26  143.52   6587250  9.435825e+08

# %%
fig = px.line(df, x="TRADEDATE", y="CLOSE", title='MOEX')
fig.show()

# %%
    df.set_index('TRADEDATE', inplace=True)
    print(df.head(), '\n')
    print(df.tail(), '\n')
    df.info()
